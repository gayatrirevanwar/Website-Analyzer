# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

import requests
from bs4 import BeautifulSoup

def scrape10(url,url_id):
        try:
            response = requests.get(url)
            if response.status_code == 200:
              soup = BeautifulSoup(response.text, 'html.parser')
              article_name = soup.find("h1",class_='tdb-title-text')
              if article_name:
                article_name = article_name.text.strip()
              article_text = soup.find("div",class_='td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type')
              if article_text:
                article_text = article_text.text.strip()
              return  article_name,article_text
            else:
             file_name = f"{url_id}.txt"
             with open(file_name, 'w', encoding='utf-8') as file:
                file.write("NA")
        except Exception as e:
            print(f"Error scraping {url}: {e}")
            return None, None

def scrape_urls_from_excel(excel_file):
    df = pd.read_excel(excel_file)
    for index, row in df.iterrows():
        url = row['URL']
        url_id = row['URL_ID']
        try:
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')
            article_name = soup.find("h1", class_='entry-title')
            if article_name:
                article_name = article_name.text.strip()
                article_text = soup.find("div", class_='td-post-content tagdiv-type')
                if article_text:
                    article_text = article_text.text.strip()
                else:
                    raise ValueError("Article text not found.")
                file_name = f"{url_id}.txt"
                with open(file_name, 'w', encoding='utf-8') as file:
                    file.write(f"Article Name: {article_name}\n")
                    file.write(f"Article Text: {article_text}")
                print(f"Article '{article_name}' saved to '{file_name}'")
            else:
                article_name, article_text = scrape10(url,url_id)
                if article_name and article_text:
                    file_name = f"{url_id}.txt"
                    with open(file_name, 'w', encoding='utf-8') as file:
                        file.write(f"Article Name: {article_name}\n")
                        file.write(f"Article Text: {article_text}")
                    print(f"Article '{article_name}' saved to '{file_name}'")
            print()
        except Exception as e:
            print(f"Error processing URL {url}: {e}")

def main():
    excel_file = r'C:\\Users\\gayat\\OneDrive\\Desktop\\BlackCoffer\\Input.xlsx'
    scrape_urls_from_excel(excel_file)

if __name__ == "__main__":
    main()
# Out:
# Article 'Rising IT cities and its impact on the economy, environment, infrastructure, and city life by the year 2040.' saved to 'blackassign0001.txt'
#
# Article 'Rising IT Cities and Their Impact on the Economy, Environment, Infrastructure, and City Life in Future' saved to 'blackassign0002.txt'
#
# Article 'Internet Demand’s Evolution, Communication Impact, and 2035’s Alternative Pathways' saved to 'blackassign0003.txt'
#
# Article 'Rise of Cybercrime and its Effect in upcoming Future' saved to 'blackassign0004.txt'
#
# Article 'OTT platform and its impact on the entertainment industry in Future.' saved to 'blackassign0005.txt'
#
# Article 'The rise of the OTT platform and its impact on the entertainment industry by 2040.' saved to 'blackassign0006.txt'
#
# Article 'Rise of Cyber Crime and its Effects' saved to 'blackassign0007.txt'
#
# Article 'Rise of Internet Demand and Its Impact on Communications and Alternatives by the Year 2035' saved to 'blackassign0008.txt'
#
# Article 'Rise of Cybercrime and its Effect by the Year 2040.' saved to 'blackassign0009.txt'
#
# Article 'Rise of Cybercrime and its Effect by the Year 2040.' saved to 'blackassign0010.txt'
#
# Article 'Rise of Internet Demand and its Impact on Communications and Alternatives by the Year 2035.' saved to 'blackassign0011.txt'
#
# Article 'Rise of telemedicine and its Impact on Livelihood by 2040' saved to 'blackassign0012.txt'
#
# Article 'Rise of e-health and its impact on humans by the year 2030' saved to 'blackassign0013.txt'
#
# Article 'Rise of e-health and its impact on humans by the year 2030' saved to 'blackassign0014.txt'
#
# Article 'Rise of telemedicine and its Impact on Livelihood by 2040' saved to 'blackassign0015.txt'
#
# Article 'Rise of telemedicine and its Impact on Livelihood by 2040' saved to 'blackassign0016.txt'
#
# Article 'Rise of Chatbots and its impact on customer support by the year 2040' saved to 'blackassign0017.txt'
#
# Article 'Rise of e-health and its impact on humans by the year 2030' saved to 'blackassign0018.txt'
#
# Article 'How does marketing influence businesses and consumers?' saved to 'blackassign0019.txt'
#
# Article 'How advertisement increase your market value?' saved to 'blackassign0020.txt'
#
# Article 'Negative effects of marketing on society' saved to 'blackassign0021.txt'
#
# Article 'How advertisement/marketing affects business.' saved to 'blackassign0022.txt'
#
# Article 'Rising IT cities will impact the economy, environment, infrastructure, and city life by the year 2035' saved to 'blackassign0023.txt'
#
# Article 'Rise of OTT platform and its impact on entertainment industry by the year 2030' saved to 'blackassign0024.txt'
#
# Article 'Rise of Electric Vehicles and its Impact on Livelihood by 2040' saved to 'blackassign0025.txt'
#
# Article 'Rise of electric vehicle and its impact on livelihood by the year 2040.' saved to 'blackassign0026.txt'
#
# Article 'Oil prices by the year 2040, and how it will impact the world economy.' saved to 'blackassign0027.txt'
#
# Article 'An outlook of healthcare by the year 2040, and how it will impact human lives.' saved to 'blackassign0028.txt'
#
# Article 'AI in healthcare to Improve Patient Outcomes' saved to 'blackassign0029.txt'
#
# Article 'What if the Creation is Taking Over the Creator?' saved to 'blackassign0030.txt'
#
# Article 'What Jobs Will Robots Take From Humans in The Future?' saved to 'blackassign0031.txt'
#
# Article 'Will Machine Replace The Human in the Future of Work?' saved to 'blackassign0032.txt'
#
# Article 'Will AI Replace Us or Work With Us?' saved to 'blackassign0033.txt'
#
# Article 'Will machine replace the human in the future of work?' saved to 'blackassign0034.txt'
#
# Article 'How humans and machines are evolving to work together?' saved to 'blackassign0035.txt'
#
# Error processing URL https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/: cannot unpack non-iterable NoneType object
# Article 'How machine learning will affect your business?' saved to 'blackassign0037.txt'
#
# Article 'Deep learning impact on areas of e-learning?' saved to 'blackassign0038.txt'
#
# Article 'How to protect future data and its privacy?' saved to 'blackassign0039.txt'
#
# Article 'How Machines, AI, Automations, and Robo-human are Effective in Finance and Banking?' saved to 'blackassign0040.txt'
#
# Article 'How Robo Human will Impact the Future?' saved to 'blackassign0041.txt'
#
# Article 'How AI will change the World?' saved to 'blackassign0042.txt'
#
# Article 'Future of Work: How AI Has Entered the Workplace' saved to 'blackassign0043.txt'
#
# Article 'How machine learning used in finance and banking?' saved to 'blackassign0044.txt'
#
# Article 'How AI will impact the future of work?' saved to 'blackassign0045.txt'
#
# Article 'All you need to know about online marketing' saved to 'blackassign0046.txt'
#
# Article 'Evolution of Advertising Industry' saved to 'blackassign0047.txt'
#
# Article 'How Data Analytics can help your business respond to the impact of COVID-19?' saved to 'blackassign0048.txt'
#
# Error processing URL https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/: cannot unpack non-iterable NoneType object
# Article 'Environmental impact of the COVID-19 pandemic – Lesson for the Future' saved to 'blackassign0050.txt'
#
# Article 'How Data Analytics and AI are used to halt the COVID-19 Pandemic?' saved to 'blackassign0051.txt'
#
# Article 'What is the difference between Artificial Intelligence, Machine Learning, Statistics, and Data Mining?' saved to 'blackassign0052.txt'
#
# Article 'How Python became the first choice for Data Science.' saved to 'blackassign0053.txt'
#
# Article 'How Google fit measure heart and respiratory rates using a phone camera?' saved to 'blackassign0054.txt'
#
# Article 'What is the future of mobile apps?' saved to 'blackassign0055.txt'
#
# Article 'Impact of AI in health and medicine' saved to 'blackassign0056.txt'
#
# Article 'What patients like and dislike about telemedicine?' saved to 'blackassign0057.txt'
#
# Article 'How we forecast future technologies?' saved to 'blackassign0058.txt'
#
# Article 'Can robots tackle late-life loneliness?' saved to 'blackassign0059.txt'
#
